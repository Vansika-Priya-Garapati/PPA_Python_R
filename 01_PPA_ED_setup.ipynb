# %% [markdown]
# # Experimental Design Setup
# Install, Import, and Check Version of Necessary Python libraries to ensure Experimental Design is realistic and executable

# %% [markdown]
# ## 1. Install Python Libraries
# Adjust versions as needed to ensure compatibility

# %%
# Install all necessary Python libraries
# !pip install Praat-Parselmouth==0.4.7 # For acoustic feature extraction and needs constant re-downloading to successfully import
# !pip install librosa==0.11.0  # For acoustic feature extraction
# !pip install pandas==2.2.2  # For data frame organization
# !pip install numpy==2.0.2 # For mathematical operations in SMOTE analysis
# !pip install imbalanced-learn==0.14.2  # To execute SMOTE analysis with Numpy
# !pip install shap==0.52.0  # Explainable AI to reveal top 20 features
# !pip install scikit-learn==1.6.0 # Has ML model - RandomForestClassifier
# !pip install matplotlib==3.10.0 # For data visualization
# !pip install seaborn==0.13.2 # For data visualization

# %% [markdown]
# ## 2. Import Libraries and Check Versions
# Importing ensures downloaded libraries can be loaded and implemented during the project. Check Versions to include the specifics in Experimental Design

# %%
import sys
import parselmouth
import librosa
import pandas
import numpy
import imblearn
import shap
import sklearn
from sklearn.ensemble import RandomForestClassifier
import matplotlib
import seaborn
import os

print(f"Python Version: {sys.version}")
print(f"Praat-Parselmouth Version: {parselmouth.__version__}")
print(f"Librosa Version: {librosa.__version__}")
print(f"Pandas Version: {pandas.__version__}")
print(f"Numpy Version: {numpy.__version__}")
print(f"Imbalanced-learn (SMOTE) Version: {imblearn.__version__}")
print(f"Shap Version: {shap.__version__}")
print(f"Scikit-learn Version: {sklearn.__version__}")
print(f"Matplotlib Version: {matplotlib.__version__}")
print(f"Seaborn Version: {seaborn.__version__}")

# %% [markdown]
# ## Finalized Versions of Current Libraries
# - Python Version: 3.12.13
# - Praat-Parselmouth Version: 0.4.7
# - Librosa Version: 0.11.0
# - Pandas Version: 2.2.2
# - Numpy Version: 2.0.2
# - Imbalanced-learn (SMOTE) Version: 0.14.2
# - Shap Version: 0.52.0
# - Scikit-learn Version: 1.6.0
# - Matplotlib Version: 3.10.0
# - Seaborn Version: 0.13.2
#
# **IMPORTANT: New packages can be added as needed to ensure code runs smooth. This Colab Notebook lists the initial list of packages included in the Experimental Design**
#
# NEXT STEP: DATA EXTRACTION
